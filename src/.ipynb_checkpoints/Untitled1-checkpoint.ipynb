# %%
using DataFrames
using Gadfly
using Cairo
using Distributions
set_default_plot_size(40cm, 14cm)

# %%
main_dir = "/home/german/labo/17/facu/"

profile_orig = readdlm(string(main_dir, "rtdos_log/1jgg_mp/profile_orig"))[:, 42]
profile_best = readdlm(string(main_dir, "rtdos_log/1jgg_mp/profile_13"))[:, 42]

profile_orig = convert(Array{Float64, 1}, profile_orig)
profile_best = convert(Array{Float64, 1}, profile_best);

# %%
# Plotteo
df_profile = DataFrame(DOPE = [profile_orig ; profile_best], AA = [ collect(1:102) ; collect(1:102) ],
Structure = repeat(["Template", "Model"], inner = [102]))

pdf_profile = plot(df_profile, x = "AA", y = "DOPE", Geom.line, color = "Structure",
Guide.title("Figure 5.A"),
Coord.cartesian(xmax = 51),
Theme(grid_line_width=1pt, key_label_font_size=14pt,
minor_label_font_size = 14pt, major_label_font_size = 20pt, key_title_font_size = 20pt))
# Out:
# Plot(...)
